# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 5**
# Preprocesamiento de datos
#
# ---

# %% [markdown]
# *   NOMBRE: Renzo Antonio Zagni Vestrini
#
#
# *   MATRÍCULA: A01795457

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 5/Actividad5_Preprocesamiento"
os.chdir(DIR)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
response_df = pd.read_csv('responses.csv')
response_df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# 1. Determina cuántas variables numéricas y cuántas de texto posee el conjunto de datos con el método `info()` y utiliza el método `describe()` del dataframe, para obtener el resumen de las estadísticas descriptivas. Separa el análisis según el tipo de datos (number, object).

# %%
response_df.info()
# Variables Numericas = 139
# Variables Objeto = 11
response_df.describe(include=[np.number]).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Columns: 150 entries, Music to House - block of flats
# dtypes: float64(134), int64(5), object(11)
# memory usage: 1.2+ MB
#                              count        mean        std   min    25%    50%  \
# Music                       1007.0    4.731877   0.664049   1.0    5.0    5.0
# Slow songs or fast songs    1008.0    3.328373   0.833931   1.0    3.0    3.0
# Dance                       1006.0    3.113320   1.170568   1.0    2.0    3.0
# Folk                        1005.0    2.288557   1.138916   1.0    1.0    2.0
# Country                     1005.0    2.123383   1.076136   1.0    1.0    2.0
# ...                            ...         ...        ...   ...    ...    ...
# Spending on healthy eating  1008.0    3.557540   1.093750   1.0    3.0    4.0
# Age                         1003.0   20.433699   2.828840  15.0   19.0   20.0
# ...

# %%
response_df.describe(include=[object]).T
# Out:
#                        count unique                  top freq
# Smoking                 1002      4        tried smoking  430
# Alcohol                 1005      3       social drinker  659
# Punctuality             1008      3  i am always on time  399
# Lying                   1008      4            sometimes  549
# Internet usage          1010      4      few hours a day  744
# Gender                  1004      2               female  593
# Left - right handed     1007      2         right handed  906
# Education               1009      6     secondary school  621
# Only child              1008      2                   no  754
# Village - town          1006      2                 city  707
# House - block of flats  1006      2       block of flats  595

# %% [markdown]
# 2. Clasifique la variable `Weight` según su escala de medición. En función de ello elija el gráfico a generar (histograma / barras) y fundamente su elección.

# %%
response_df['Weight'].hist(bins=20)
# La variable Weight es una variable quantitativa (numerica) continua
# El uso del histograma es el mas recomendado para este tipo de valriables
# ya que nos muestra la distribucion del peso en la muestra asi como nos permite
# analizar estos utilizando mediciones de tendencia central, variabilidad y forma
# Out:
# <Axes: >

# %% [markdown]
# 3. Clasifique la distribución del peso según su asimetría, justificando tu respuesta. Incluye el cálculo numérico que lo demuestra.

# %%
weight_hist = response_df['Weight'].hist(bins=20)
weight_hist.axvline(response_df['Weight'].mean(), color='k', linestyle='dashed', linewidth=1)
weight_hist.axvline(response_df['Weight'].median(), color='r', linestyle='solid', linewidth=1)
weight_skew = response_df['Weight'].skew()
weight_kurt = response_df['Weight'].kurt()
print("Skew: " + str(weight_skew) + " Kurtosis: " + str(weight_kurt) + "\n")

# La distribución del peso es de sesgo positivo (skew > 0)
# y de tipo leptocurtica (curtosis > 3)
# Out:
# Skew: 1.2237251927527477 Kurtosis: 3.969322481289579

# %% [markdown]
# 4. ¿Cuántos valores faltantes tiene la variable `Weight`? ¿Qué porcentaje representa?

# %%
print("Numero de valores faltantes de la variable Weight=" + str(response_df['Weight'].isna().sum()))
# Out:
# Numero de valores faltantes de la variable Weight=20

# %% [markdown]
# 5. ¿Tendrán los valores faltantes de `Weight` relación con alguna otra variable? Analízalo considerando las siguientes columnas:
# *   Numéricas: `Age, Number of siblings`
# *   Categóricas: `Gender, Education`
#
# Para ello deberás dividir cada columna en dos grupos: con/sin faltantes en `Weight` y utilizar métodos gráficos y la prueba t para ver si hay diferencias significativas.
#
# **NOTA**. Puedes reutilizar las funciones `Diagnose_MV_Numerical` y `Diagnose_MV_Categorical` definidas en Hands-On-Prep_Missing_Values.zip. Revisa nuevamente cómo utilizarlas.

# %%
BM_MV = response_df.Weight.isna()
BM_MV
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1005    False
# 1006    False
# 1007    False
# 1008    False
# 1009    False
# Name: Weight, Length: 1010, dtype: bool

# %%
from scipy.stats import ttest_ind
def Diagnose_MV_Numerical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    labels=[]
    box_sr = pd.Series('',index = BM_MV.unique())
    for poss in BM_MV.unique():
        BM = BM_MV == poss
        box_sr[poss] = df[BM][str_att_name].dropna()
        labels.append(MV_labels[poss])

    plt.boxplot(box_sr,vert=False)
    plt.yticks([1,2],labels)
    plt.xlabel(str_att_name)
    plt.show()

    plt.figure(figsize=(10,4))

    att_range = (df[str_att_name].min(),df[str_att_name].max())

    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].hist()
        plt.xlim = att_range
        plt.xlabel(str_att_name)
        plt.title(MV_labels[poss])

    plt.show()

    group_1_data = df[BM_MV][str_att_name].dropna()
    group_2_data = df[~BM_MV][str_att_name].dropna()

    p_value = ttest_ind(group_1_data,group_2_data).pvalue

    print('p-value of t-test: {}'.format(p_value))

# %%
from scipy.stats import chi2_contingency
def Diagnose_MV_Categorical(df,str_att_name,BM_MV):
    MV_labels = {True:'With Missing Values',False:'Without Missing Values'}

    plt.figure(figsize=(10,4))
    for i,poss in enumerate(BM_MV.unique()):
        plt.subplot(1,2,i+1)
        BM = BM_MV == poss
        df[BM][str_att_name].value_counts().plot.bar()
        plt.title(MV_labels[poss])
    plt.show()

    contigency_table = pd.crosstab(BM_MV,df[str_att_name])
    p_value = chi2_contingency(contigency_table)[1]

    print('p-value of Chi_squared test: {}'.format(p_value))

# %%
numerical_attributes = ['Age', 'Number of siblings']

BM_MV = response_df.Weight.isna()
for att in numerical_attributes:
    print('Diagnosis Analysis of Missing Values for {}:'.format(att))
    Diagnose_MV_Numerical(response_df,att,BM_MV)
    print('- - - - - - - - - - - - divider - - - - - - - - - - - ')
# Out:
# Diagnosis Analysis of Missing Values for Age:
# p-value of t-test: 0.7258243979822129
# - - - - - - - - - - - - divider - - - - - - - - - - -
# Diagnosis Analysis of Missing Values for Number of siblings:
# p-value of t-test: 0.8255092107556896
# - - - - - - - - - - - - divider - - - - - - - - - - -

# %%
# Variables Numericas: Numero de hermanos y Edad
# -----------------------------------------------
# Los p-value son > 0.05 por lo que  podemos concluir que el Numero de hermanos
# o la Edad no afectan la existencia de valores faltantes en el atributo Peso

# %%
categorical_attributes = ['Gender', 'Education']

BM_MV = response_df.Weight.isna()
for att in categorical_attributes:
    print('Diagnosis Analysis of Missing Values for {}:'.format(att))
    Diagnose_MV_Categorical(response_df,att,BM_MV)
    print('- - - - - - - - - - - - divider - - - - - - - - - - - ')
# Out:
# Diagnosis Analysis of Missing Values for Gender:
# p-value of Chi_squared test: 0.5472167199163878
# - - - - - - - - - - - - divider - - - - - - - - - - -
# Diagnosis Analysis of Missing Values for Education:
# p-value of Chi_squared test: 0.8424822989541867
# - - - - - - - - - - - - divider - - - - - - - - - - -

# %%
# Variables categoricas: Educacion y Genero
# Los p-values resultantes del test Chi al cuadrado son > 0.05 por lo que
# podemos concluir que no hay relacion entre los valores faltantes del
# atributo Peso y la Educacion o el Genero

# %% [markdown]
# 6. Utiliza una medida de tendencia central para imputar los valores faltantes de `Weight`. ¿Cuál es recomendable y por qué?

# %%
response_df['Weight'].fillna(value=response_df['Weight'].median(), inplace=True)
# Se utiliza la mediana como medida de tendencia central para imputar los valores
# faltantes ya estos son del tipo MAR y la variable es sesgada

# %% [markdown]
# 7. ¿Hay valores atípicos de la variable `Weight`? Confírmalo con un gráfico de boxplot. ¿Cuántos son? Almacénalos en un dataframe independiente y elimínalos del conjunto original.

# %%
response_df['Weight'].plot.box(vert=False)
# Out:
# <Axes: >

# %%
# En la grafica podemos observar la existencia de valores atipicos
# por encima del cuarto quartile (Q4)
# Calculamos Q1, Q3 y IQR
Q1 = response_df['Weight'].quantile(0.25)
Q3 = response_df['Weight'].quantile(0.75)
IQR = Q3 - Q1
LimitMax = Q3 + 1.5 * IQR
# Identificamos outliers > Q3 + 1.5 * IQR y alamacenamos los registros
# en dataframe independiente
weight_df  = response_df[response_df['Weight'] > LimitMax]
# Eliminamos los valores atipicos
response_df.drop(response_df[response_df.Weight > LimitMax].index, inplace=True)

# %% [markdown]
# 8. Repite el mismo proceso de valores atípicos con la variable `Height`.

# %%
response_df['Height'].plot.box(vert=False)
# Out:
# <Axes: >

# %%
# Tenemos valores atipicos sobre y bajo los quratlies Q4 y Q1 respectivamente
# Calculamos Q1, Q3 y IQR
Q1 = response_df['Height'].quantile(0.25)
Q3 = response_df['Height'].quantile(0.75)
IQR = Q3 - Q1
LimitMax = Q3 + 1.5 * IQR
LimitMin = Q1 - 1.5 * IQR
# Identificamos outliers > Q3 + 1.5 * IQR y < Q1 - 1.5 IQR
# alamacenamos registros en dataframe independient
height_df  = response_df[(response_df['Height'] < LimitMin) | (response_df['Height'] > LimitMax)]
# Eliminamos los valores atipicos
response_df.drop(response_df[(response_df['Height'] < LimitMin) | (response_df['Height'] > LimitMax)].index, inplace=True)

# %% [markdown]
# 9. ¿Hay encuestados que sean atípicos según su índice de masa corporal (`BMI`)? El `BMI` puede ser calculado usando la siguiente fórmula:
#
# `BMI = Weight / Height ^ 2`
#
# **NOTA**. El peso tiene que estar en kilogramos y la altura en metros, pero en el conjunto la altura se ha registrado en centímetros, por lo que deberás convertirla a metros.

# %%
response_df['BMI'] = response_df['Weight'] / (response_df['Height']/100) **2

# %%
response_df['BMI'].plot.box(vert=False)
# Existen 6 valores atipicos por encima de cuatro quartil
# Calculos en la siguiente celda
# Out:
# <Axes: >

# %%
Q1 = response_df['BMI'].quantile(0.25)
Q3 = response_df['BMI'].quantile(0.75)
IQR = Q3 - Q1
LimitMax = Q3 + 1.5 * IQR
bmi_df  = response_df[response_df['BMI'] > LimitMax]
bmi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 42 to 636
# Columns: 151 entries, Music to BMI
# dtypes: float64(135), int64(5), object(11)
# memory usage: 7.1+ KB

# %%
list(response_df.select_dtypes(['object']).columns)
# Out:
# ['Smoking',
#  'Alcohol',
#  'Punctuality',
#  'Lying',
#  'Internet usage',
#  'Gender',
#  'Left - right handed',
#  'Education',
#  'Only child',
#  'Village - town',
#  'House - block of flats']

# %% [markdown]
# 10. Utiliza boxplots para visualizar la distribución del `BMI` según cada una de las variables categóricas de texto. Comenta un hallazgo que llame tu atención.

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
#for col_name in list(response_df.select_dtypes(['object']).columns):
#  sns.boxplot(x=response_df['BMI'],y=response_df[col_name])
for col_name in list(response_df.select_dtypes(['object']).columns):
    plt.figure()
    plt.tight_layout()
    sns.set(rc={"figure.figsize":(8, 5)})
    f, (ax_box) = plt.subplots(1, sharex=True)
    plt.gca().set(xlabel= col_name,ylabel='BMI')
    sns.boxplot(response_df, x='BMI', y=col_name, linewidth= 1.0)

# El hallazgo que mas llama mi atencion es el la visualizacion de la distribucion
# del BMI segun la variable Educacion y de como los que su nivel de educacion
# es el mas alto tienes tambien el BMI mas elevado
